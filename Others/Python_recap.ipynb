# %%
print("Hello world!")
# Out:
# Hello world!

# %% [markdown]
# **Part 1**

# %%
# Font sizes

# %% [markdown]
# # Biggest size
# ## Large size
# ### Medium size
# #### Smaller

# %% [markdown]
# # Types of Waste

# %% [markdown]
# ## Types of Waste
# - *Plastics*
# - *Paper*
# - *Organic*

# %% [markdown]
# - **Plastics**
# - **Paper**
# - **Organic**

# %% [markdown]
# $a^2 + b^2 = c^2$

# %%
age = 20
age
# Out:
# 20

# %%
age = 21
age
# Out:
# 21

# %% [markdown]
# <font color="red">This is red text</font>

# %% [markdown]
# # <font color="red">This is red text</font>

# %% [markdown]
# <font color="red">This is red text</font>

# %%
age = 21, "Joseph"

# %%
age
# Out:
# (21, 'Joseph')

# %%
age = 21, "Joseph"; 18, "Mighty"
# Out:
# (18, 'Mighty')

# %%
age
# Out:
# (21, 'Joseph')

# %%
age = 21, "Joseph"; 18, "Mighty"
# Out:
# (18, 'Mighty')

# %%
age
# Out:
# (21, 'Joseph')

# %%
Total = 10000
Doctors = 25
Nurses = 12
Duration = Total / ((Doctors + Nurses) * 3)
Duration
# Out:
# 90.09009009009009

# %%
patient_1 = "Amponsah"
gender = "Male"
patient_bmi = 20
print(f"Patient's name is {patient_1}.\nHe is a {gender}.\nHe has a bmi of {patient_bmi}.")
# Out:
# Patient's name is Amponsah.
# He is a Male.
# He has a bmi of 20.

# %%
patient_1 = "Mr Amponsah"
gender = "Male"
patient_bmi = float(22.5)
glucose_level = float(32.5)
patient_diabetic = True

patient_report = f"Patient name is {patient_1}.\nHe has a BMI of {patient_bmi}."
print(patient_report)
# Out:
# Patient name is Mr Amponsah.
# He has a BMI of 22.5.

# %%
class_list = ["Linda", "Dabuo", "Peter", "Brian", "Precious", 23, 21, 25, 20, 22]
#class_list[1] = "Louis"
#print(f"Sir {class_list[1]} is our Biomedical Data Analysis Lecturer.")
#class_list[0:2]
class_list[-8:-2]
class_list
class_list[:5]
class_list.insert(2, "Lion")
class_list
# Out:
# ['Linda', 'Dabuo', 'Lion', 'Peter', 'Brian', 'Precious', 23, 21, 25, 20, 22]
